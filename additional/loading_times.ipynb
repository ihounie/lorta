# %%
# Jupyter Notebook Cell
import torch
import time
import numpy as np
import pandas as pd

# -------------------------------
# Configuration Parameters
# -------------------------------

# Fixed Dimensions
L = 32          # Parameter for tensor shapes in Lorta
h = 32          # Parameter for tensor shapes in Lorta
d = 4096        # Assumed to be d_in for Lora
d_out = 128     # Parameter for tensor shapes in Lorta
m = 2

# Variable Parameters
r_list = [4, 64]             # Ranks to test
N_list = [10, 100]        # Number of repetitions

# Transfer settings
n_repetitions = 10  # Number of repetitions for timing

# Jupyter Notebook Cell

import torch
import time
import numpy as np
import pandas as pd

# -------------------------------
# Configuration Parameters
# -------------------------------

# Fixed Dimensions
L = 80          # Parameter for tensor shapes in Lorta
h = 32          # Parameter for tensor shapes in Lorta
d = 4096        # Assumed to be d_in for Lora
d_out = 128     # Parameter for tensor shapes in Lorta

# Variable Parameters
r_list = [4, 64]             # Ranks to test
N_list = [1, 10, 100]        # Number of repetitions

# Transfer settings
n_repetitions = 10  # Number of repetitions for timing

# Output CSV filename
output_csv = 'gpu_transfer_times_enhanced.csv'

# -------------------------------
# Data Preparation Functions
# -------------------------------

def prepare_lora_tensors(N, r):
    """
    Prepares batched tensors for Lora.
    Instead of creating N * L * d individual tensors, we create a single batched tensor.
    Shape: (N * L * d, d_in, r)
    """
    total_tensors = N * L * d
    d_in = d  # Assuming d_in equals d
    # To manage memory, create in smaller batches if needed
    # Here, we create a single large tensor
    lora_tensor = torch.randn(total_tensors, d_in, r)
    return lora_tensor

def prepare_lorta_tensors(N, r):
    """
    Prepares tuples of tensors for Lorta.
    Each tuple contains four tensors with shapes:
    [(L, r), (h, r), (d_out/h, r), (d_in, r)]
    """
    assert d_out % h == 0, "d_out must be divisible by h."
    d_out_per_tensor = d_out // h
    d_in = d  # Assuming d_in equals d
    lorta_tuples = []
    for _ in range(N):
        tuple_tensors = (
            torch.randn(L, r),
            torch.randn(h, r),
            torch.randn(d_out_per_tensor, r),
            torch.randn(d_in, r)
        )
        lorta_tuples.append(tuple_tensors)
    return lorta_tuples

# -------------------------------
# Warm-up GPU
# -------------------------------

def warm_up_gpu(lora_tensor_sample, lorta_tuples_sample):
    """
    Performs a warm-up transfer to the GPU to stabilize performance.
    """
    print("Warming up GPU...")
    # Transfer a small sample of Lora tensors
    _ = lora_tensor_sample.cuda()
    # Transfer a small sample of Lorta tuples
    for tuple_tensors in lorta_tuples_sample:
        for tensor in tuple_tensors:
            _ = tensor.cuda()
    torch.cuda.synchronize()
    print("Warm-up completed.\n")

# -------------------------------
# Transfer Timing Functions
# -------------------------------

def transfer_lora(lora_tensor):
    """
    Transfers the Lora tensor to the GPU.
    """
    _ = lora_tensor.cuda()
    torch.cuda.synchronize()

def transfer_lorta(lorta_tuples):
    """
    Transfers all tensors in Lorta tuples to the GPU.
    """
    for tuple_tensors in lorta_tuples:
        for tensor in tuple_tensors:
            _ = tensor.cuda()
    torch.cuda.synchronize()

# -------------------------------
# Memory Cleanup Function
# -------------------------------

def cleanup_memory():
    """
    Frees GPU memory by deleting variables and clearing the CUDA cache.
    """
    del torch
    torch.cuda.empty_cache()

# -------------------------------
# Measurement and Results
# -------------------------------

# Initialize a list to store results
results = []

# Iterate over each combination of rank and N
for r in r_list:
    for N in N_list:
        print(f"Testing with r={r} and N={N}...")
        
        # Prepare tensors
        try:
            lora_tensor = prepare_lora_tensors(N, r)
            lorta_tuples = prepare_lorta_tensors(N, r)
        except RuntimeError as e:
            print(f"  Error in tensor preparation: {e}")
            print(f"  Skipping r={r}, N={N}.\n")
            continue
        
        # Perform warm-up transfer
        # Use a small subset to avoid long warm-up times
        lora_tensor_sample = lora_tensor[:10] if N * L * d >=10 else lora_tensor
        lorta_tuples_sample = lorta_tuples[:10] if N >=10 else lorta_tuples
        warm_up_gpu(lora_tensor_sample, lorta_tuples_sample)
        
        # Initialize lists to store transfer times
        times_lora = []
        times_lorta = []
        
        print(f"  Starting transfer measurements for r={r}, N={N}...")
        
        for rep in range(1, n_repetitions + 1):
            print(f"    Repetition {rep}/{n_repetitions}")
            
            # Measure Lora transfer
            start_time = time.time()
            transfer_lora(lora_tensor)
            end_time = time.time()
            transfer_time_lora = end_time - start_time
            times_lora.append(transfer_time_lora)
            print(f"      Lora Transfer Time: {transfer_time_lora:.6f} seconds")
            
            # Measure Lorta transfer
            start_time = time.time()
            transfer_lorta(lorta_tuples)
            end_time = time.time()
            transfer_time_lorta = end_time - start_time
            times_lorta.append(transfer_time_lorta)
            print(f"      Lorta Transfer Time: {transfer_time_lorta:.6f} seconds\n")
        
        # Calculate statistics
        avg_lora = np.mean(times_lora)
        std_lora = np.std(times_lora)
        avg_lorta = np.mean(times_lorta)
        std_lorta = np.std(times_lorta)
        
        # Store the results in a single row
        results.append({
            'Rank (r)': r,
            'Repetitions (N)': N,
            'Lora_Average_Transfer_Time (s)': avg_lora,
            'Lora_Std_Dev (s)': std_lora,
            'Lorta_Average_Transfer_Time (s)': avg_lorta,
            'Lorta_Std_Dev (s)': std_lorta
        })
        
        print(f"  Completed measurements for r={r}, N={N}.\n")
        
        # Memory Cleanup (Not included in timing)
        del lora_tensor
        del lorta_tuples
        torch.cuda.empty_cache()
        
# -------------------------------
# Display Results
# -------------------------------

# Convert results to a pandas DataFrame for better visualization
results_df = pd.DataFrame(results)

# Display the results
print("Transfer Time Comparison Results:")
display(results_df)

# -------------------------------
# Save Results to CSV
# -------------------------------

# Save the DataFrame to a CSV file
results_df.to_csv(output_csv, index=False)
print(f"\nResults have been saved to '{output_csv}'.")
# Out:
# Testing with r=4 and N=10...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 115
#     113 # Prepare tensors
#     114 try:
# --> 115     lora_tensor = prepare_lora_tensors(N, r)
#     116     lorta_tuples = prepare_lorta_tensors(N, r)
#     117 except RuntimeError as e:
#
# Cell In[1], line 39, in prepare_lora_tensors(N, r)
#      36 d_in = d  # Assuming d_in equals d
#      37 # To manage memory, create in smaller batches if needed
#      38 # Here, we create a single large tensor
# ---> 39 lora_tensor = torch.randn(total_tensors, d_in, r)
#      40 return lora_tensor
#
# KeyboardInterrupt:

# %%
# Jupyter Notebook Cell

import torch
import time
import numpy as np
import pandas as pd

# -------------------------------
# Configuration Parameters
# -------------------------------

# Fixed Dimensions
L = 80          # Parameter for tensor shapes in Lorta and Lotr
h = 32          # Parameter for tensor shapes in Lorta
d = 4096        # Assumed to be d_in for Lora
d_out = 128     # Parameter for tensor shapes in Lorta
M = 2

# Variable Parameters
r_list = [4, 64]             # Ranks to test
N_list = [1, 10, 100]        # Number of repetitions

# Transfer settings
n_repetitions = 100  # Number of repetitions for timing

# Output CSV filename
output_csv = 'gpu_transfer_times_enhanced_with_lotr.csv'

# -------------------------------
# Data Preparation Functions
# -------------------------------

def prepare_lora_tensors(N, r):
    """
    Prepares batched tensors for Lora.
    Instead of creating N * L individual tensors, we create a single batched tensor.
    Shape: (N * L,  d, d_in, r)
    """
    d_in = d  # Assuming d_in equals d
    # To manage memory, create in smaller batches if needed
    # Here, we create a single large tensor
    lora_tensor = torch.randn(2, N, M, L, d_in, r)
    return lora_tensor

def prepare_lorta_tensors(N, r):
    """
    Prepares tuples of tensors for Lorta.
    Each tuple contains four tensors with shapes:
    [(L, r), (h, r), (d_out/h, r), (d_in, r)]
    """
    assert d_out % h == 0, "d_out must be divisible by h."
    d_out_per_tensor = d_out // h
    d_in = d  # Assuming d_in equals d
    lorta_tuples = (
        torch.randn(N, L, r),
        torch.randn(N, h, r),
        torch.randn(N, d_out_per_tensor, r),
        torch.randn(N,d_in, r), 
        torch.randn(N,  M, r), 
    )
    return lorta_tuples

def prepare_lotr_tensors(N, r):
    """
    Prepares tuples of tensors for Lotr.
    Each tuple contains three tensors with shapes:
    [(L, r, r), (d, r), (d, r)]
    """
    tuple_tensors = (
        torch.randn(N, M, L, r, r),  # 3D tensor
        torch.randn(N, M, d, r),      # 2D tensor
        torch.randn(N, M, d, r)       # 2D tensor
    )
    return tuple_tensors

# -------------------------------
# Warm-up GPU
# -------------------------------

def warm_up_gpu(lora_tensor_sample, lorta_tuples_sample, lotr_tuples_sample):
    """
    Performs a warm-up transfer to the GPU to stabilize performance.
    """
    print("Warming up GPU...")
    # Transfer a small sample of Lora tensors
    _ = lora_tensor_sample.cuda()
    # Transfer a small sample of Lorta tuples
    for tuple_tensors in lorta_tuples_sample:
        for tensor in tuple_tensors:
            _ = tensor.cuda()
    # Transfer a small sample of Lotr tuples
    for tuple_tensors in lotr_tuples_sample:
        for tensor in tuple_tensors:
            _ = tensor.cuda()
    torch.cuda.synchronize()
    print("Warm-up completed.\n")

# -------------------------------
# Transfer Timing Functions
# -------------------------------

def transfer_lora(lora_tensor):
    """
    Transfers the Lora tensor to the GPU.
    """
    lora_tensor.cuda()
    torch.cuda.synchronize()
    return lora_tensor

def transfer_lorta(lorta_tuples):
    """
    Transfers all tensors in Lorta tuples to the GPU.
    """
    gpu_tuple = tuple(tensor.cuda() for tensor in lorta_tuples)
    torch.cuda.synchronize()
    return gpu_tuple

def transfer_lotr(lotr_tuples):
    """
    Transfers all tensors in Lotr tuples to the GPU.
    """
    gpu_tuple = tuple(tensor.cuda() for tensor in lotr_tuples)
    torch.cuda.synchronize()
    return gpu_tuple

# -------------------------------
# Memory Cleanup Function
# -------------------------------

def cleanup_memory(lora_tensor=None, lorta_tuples=None, lotr_tuples=None):
    """
    Frees GPU memory by deleting variables and clearing the CUDA cache.
    """
    if lora_tensor is not None:
        del lora_tensor
    if lorta_tuples is not None:
        del lorta_tuples
    if lotr_tuples is not None:
        del lotr_tuples
    torch.cuda.empty_cache()

# -------------------------------
# Measurement and Results
# -------------------------------

# Initialize a list to store results
results = []

# Iterate over each combination of rank and N
for r in r_list:
    for N in N_list:
        print(f"Testing with r={r} and N={N}...")
        
        # Prepare tensors
        try:
            lora_tensor = prepare_lora_tensors(N, r)
            lorta_tuples = prepare_lorta_tensors(N, r)
            lotr_tuples = prepare_lotr_tensors(N, r)
        except RuntimeError as e:
            print(f"  Error in tensor preparation: {e}")
            print(f"  Skipping r={r}, N={N}.\n")
            continue
        
        # Perform warm-up transfer
        # Use a small subset to avoid long warm-up times
        lora_tensor_sample = lora_tensor[:10] if (N * L * d) >= 10 else lora_tensor
        lorta_tuples_sample = lorta_tuples[:10] if N >= 10 else lorta_tuples
        lotr_tuples_sample = lotr_tuples[:10] if N >= 10 else lotr_tuples
        warm_up_gpu(lora_tensor_sample, lorta_tuples_sample, lotr_tuples_sample)
        
        # Initialize lists to store transfer times
        times_lora = []
        times_lorta = []
        times_lotr = []
        
        print(f"  Starting transfer measurements for r={r}, N={N}...")
        
        for rep in range(1, n_repetitions + 1):
            print(f"    Repetition {rep}/{n_repetitions}")
            
            # Measure Lora transfer
            start_time = time.time()
            gpu_lora = transfer_lora(lora_tensor)
            end_time = time.time()
            transfer_time_lora = end_time - start_time
            times_lora.append(transfer_time_lora)
            cleanup_memory(gpu_lora)
            print(f"      Lora Transfer Time: {transfer_time_lora:.6f} seconds")
            
            # Measure Lorta transfer
            start_time = time.time()
            gpu_lorta = transfer_lorta(lorta_tuples)
            end_time = time.time()
            cleanup_memory(None, [gpu_lorta])
            transfer_time_lorta = end_time - start_time
            times_lorta.append(transfer_time_lorta)
            print(f"      Lorta Transfer Time: {transfer_time_lorta:.6f} seconds")
            
            # Measure Lotr transfer
            start_time = time.time()
            gpu_lotr = transfer_lotr(lotr_tuples)
            cleanup_memory(None, None, [gpu_lotr])
            end_time = time.time()
            transfer_time_lotr = end_time - start_time
            times_lotr.append(transfer_time_lotr)
            print(f"      Lotr Transfer Time: {transfer_time_lotr:.6f} seconds\n")
        
        # Calculate statistics
        avg_lora = np.mean(times_lora)
        std_lora = np.std(times_lora)
        avg_lorta = np.mean(times_lorta)
        std_lorta = np.std(times_lorta)
        avg_lotr = np.mean(times_lotr)
        std_lotr = np.std(times_lotr)
        
        # Store the results in a single row
        results.append({
            'Rank (r)': r,
            'Repetitions (N)': N,
            'Lora_Average_Transfer_Time (s)': avg_lora,
            'Lora_Std_Dev (s)': std_lora,
            'Lorta_Average_Transfer_Time (s)': avg_lorta,
            'Lorta_Std_Dev (s)': std_lorta,
            'Lotr_Average_Transfer_Time (s)': avg_lotr,
            'Lotr_Std_Dev (s)': std_lotr
        })
        
        print(f"  Completed measurements for r={r}, N={N}.\n")
        
        # Memory Cleanup (Not included in timing)
        #cleanup_memory(lora_tensor, lorta_tuples, lotr_tuples)
        
# -------------------------------
# Display Results
# -------------------------------

# Convert results to a pandas DataFrame for better visualization
results_df = pd.DataFrame(results)

# Display the results
print("Transfer Time Comparison Results:")
display(results_df)

# -------------------------------
# Save Results to CSV
# -------------------------------

# Save the DataFrame to a CSV file
results_df.to_csv(output_csv, index=False)
print(f"\nResults have been saved to '{output_csv}'.")
# Out:
# Testing with r=4 and N=1...
# Warming up GPU...
# Warm-up completed.
#
#   Starting transfer measurements for r=4, N=1...
#     Repetition 1/100
#       Lora Transfer Time: 0.893523 seconds
#       Lorta Transfer Time: 0.000326 seconds
#       Lotr Transfer Time: 0.002485 seconds
#
#     Repetition 2/100
#       Lora Transfer Time: 0.012233 seconds
#       Lorta Transfer Time: 0.000122 seconds
#       Lotr Transfer Time: 0.001609 seconds
#
#     Repetition 3/100
#       Lora Transfer Time: 0.004706 seconds
#       Lorta Transfer Time: 0.000114 seconds
#       Lotr Transfer Time: 0.000385 seconds
#
#     Repetition 4/100
#       Lora Transfer Time: 0.001386 seconds
#       Lorta Transfer Time: 0.000109 seconds
#       Lotr Transfer Time: 0.000391 seconds
#
#     Repetition 5/100
#       Lora Transfer Time: 0.001451 seconds
#       Lorta Transfer Time: 0.000121 seconds
#       Lotr Transfer Time: 0.000380 seconds
#
#     Repetition 6/100
#       Lora Transfer Time: 0.001403 seconds
#       Lorta Transfer Time: 0.000115 seconds
#       Lotr Transfer Time: 0.000386 seconds
#
#     Repetition 7/100
#       Lora Transfer Time: 0.001413 seconds
#       Lorta Transfer Time: 0.000113 seconds
#       Lotr Transfer Time: 0.000391 seconds
#
#     Repetition 8/100
#       Lora Transfer Time: 0.001392 seconds
#       Lorta Transfer Time: 0.000112 seconds
#       Lotr Transfer Time: 0.000391 seconds
#
#     Repetition 9/100
#       Lora Transfer Time: 0.001420 seconds
#       Lorta Transfer Time: 0.000113 seconds
#       Lotr Transfer Time: 0.000391 seconds
#
#     Repetition 10/100
#       Lora Transfer Time: 0.001404 seconds
#       Lorta Transfer Time: 0.000108 seconds
#       Lotr Transfer Time: 0.000397 seconds
#
#     Repetition 11/100
#       Lora Transfer Time: 0.001431 seconds
#       Lorta Transfer Time: 0.000112 seconds
#       Lotr Transfer Time: 0.000391 seconds
#
#     Repetition 12/100
#       Lora Transfer Time: 0.001388 seconds
#       Lorta Transfer Time: 0.000108 seconds
#       Lotr Transfer Time: 0.000396 seconds
#
#     Repetition 13/100
#       Lora Transfer Time: 0.001399 seconds
#       Lorta Transfer Time: 0.000111 seconds
#       Lotr Transfer Time: 0.000391 seconds
#
#     Repetition 14/100
#       Lora Transfer Time: 0.001388 seconds
#       Lorta Transfer Time: 0.000107 seconds
#       Lotr Transfer Time: 0.000399 seconds
#
#     Repetition 15/100
#       Lora Transfer Time: 0.001430 seconds
#       Lorta Transfer Time: 0.000113 seconds
#       Lotr Transfer Time: 0.000390 seconds
#
#     Repetition 16/100
#       Lora Transfer Time: 0.001388 seconds
#       Lorta Transfer Time: 0.000112 seconds
#       Lotr Transfer Time: 0.000408 seconds
#
#     Repetition 17/100
#       Lora Transfer Time: 0.001382 seconds
#       Lorta Transfer Time: 0.000110 seconds
#       Lotr Transfer Time: 0.000387 seconds
#
#     Repetition 18/100
#       Lora Transfer Time: 0.001390 seconds
#       Lorta Transfer Time: 0.000105 seconds
#       Lotr Transfer Time: 0.000399 seconds
#
#     Repetition 19/100
#       Lora Transfer Time: 0.001394 seconds
#       Lorta Transfer Time: 0.000110 seconds
#       Lotr Transfer Time: 0.000392 seconds
#
#     Repetition 20/100
#       Lora Transfer Time: 0.001386 seconds
#       Lorta Transfer Time: 0.000111 seconds
#       Lotr Transfer Time: 0.000394 seconds
#
#     Repetition 21/100
#       Lora Transfer Time: 0.001399 seconds
#       Lorta Transfer Time: 0.000107 seconds
#       Lotr Transfer Time: 0.000398 seconds
#
#     Repetition 22/100
#       Lora Transfer Time: 0.001403 seconds
#       Lorta Transfer Time: 0.000128 seconds
#       Lotr Transfer Time: 0.000375 seconds
#
#     Repetition 23/100
#       Lora Transfer Time: 0.001403 seconds
#       Lorta Transfer Time: 0.000108 seconds
#       Lotr Transfer Time: 0.000395 seconds
#
#     Repetition 24/100
#       Lora Transfer Time: 0.001394 seconds
#       Lorta Transfer Time: 0.000115 seconds
#       Lotr Transfer Time: 0.000387 seconds
#
#     Repetition 25/100
#       Lora Transfer Time: 0.001400 seconds
#       Lorta Transfer Time: 0.000109 seconds
#       Lotr Transfer Time: 0.000394 seconds
#
#     Repetition 26/100
#       Lora Transfer Time: 0.001410 seconds
#       Lorta Transfer Time: 0.000110 seconds
#       Lotr Transfer Time: 0.000381 seconds
#
#     Repetition 27/100
#       Lora Transfer Time: 0.001391 seconds
#       Lorta Transfer Time: 0.000103 seconds
#       Lotr Transfer Time: 0.000400 seconds
#
#     Repetition 28/100
#       Lora Transfer Time: 0.001399 seconds
#       Lorta Transfer Time: 0.000108 seconds
#       Lotr Transfer Time: 0.000394 seconds
#
#     Repetition 29/100
#       Lora Transfer Time: 0.001388 seconds
#       Lorta Transfer Time: 0.000106 seconds
#       Lotr Transfer Time: 0.000395 seconds
#
#     Repetition 30/100
#       Lora Transfer Time: 0.001423 seconds
#       Lorta Transfer Time: 0.000115 seconds
#       Lotr Transfer Time: 0.000377 seconds
#
#     Repetition 31/100
#       Lora Transfer Time: 0.001383 seconds
#       Lorta Transfer Time: 0.000111 seconds
#       Lotr Transfer Time: 0.000392 seconds
#
#     Repetition 32/100
#       Lora Transfer Time: 0.001409 seconds
#       Lorta Transfer Time: 0.000111 seconds
#       Lotr Transfer Time: 0.000391 seconds
#
#     Repetition 33/100
#       Lora Transfer Time: 0.001384 seconds
#       Lorta Transfer Time: 0.000107 seconds
#       Lotr Transfer Time: 0.000394 seconds
#
#     Repetition 34/100
#       Lora Transfer Time: 0.001426 seconds
#       Lorta Transfer Time: 0.000110 seconds
#       Lotr Transfer Time: 0.000392 seconds
#
#     Repetition 35/100
#       Lora Transfer Time: 0.001397 seconds
#       Lorta Transfer Time: 0.000107 seconds
#       Lotr Transfer Time: 0.000396 seconds
#
#     Repetition 36/100
#       Lora Transfer Time: 0.001412 seconds
#       Lorta Transfer Time: 0.000111 seconds
#       Lotr Transfer Time: 0.000391 seconds
#
#     Repetition 37/100
#       Lora Transfer Time: 0.001388 seconds
#       Lorta Transfer Time: 0.000107 seconds
#       Lotr Transfer Time: 0.000396 seconds
#
#     Repetition 38/100
#       Lora Transfer Time: 0.001411 seconds
#       Lorta Transfer Time: 0.000107 seconds
#       Lotr Transfer Time: 0.000397 seconds
#
#     Repetition 39/100
#       Lora Transfer Time: 0.001389 seconds
#       Lorta Transfer Time: 0.000108 seconds
#       Lotr Transfer Time: 0.000396 seconds
#
#     Repetition 40/100
#       Lora Transfer Time: 0.001424 seconds
#       Lorta Transfer Time: 0.000110 seconds
#       Lotr Transfer Time: 0.000393 seconds
#
#     Repetition 41/100
#       Lora Transfer Time: 0.001386 seconds
#       Lorta Transfer Time: 0.000110 seconds
#       Lotr Transfer Time: 0.000393 seconds
#
#     Repetition 42/100
#       Lora Transfer Time: 0.001380 seconds
#       Lorta Transfer Time: 0.000114 seconds
#       Lotr Transfer Time: 0.000390 seconds
#
#     Repetition 43/100
#       Lora Transfer Time: 0.001389 seconds
#       Lorta Transfer Time: 0.000111 seconds
#       Lotr Transfer Time: 0.000394 seconds
#
#     Repetition 44/100
#       Lora Transfer Time: 0.001398 seconds
#       Lorta Transfer Time: 0.000110 seconds
#       Lotr Transfer Time: 0.000393 seconds
#
#     Repetition 45/100
#       Lora Transfer Time: 0.001385 seconds
#       Lorta Transfer Time: 0.000108 seconds
#       Lotr Transfer Time: 0.000385 seconds
#
#     Repetition 46/100
#       Lora Transfer Time: 0.001382 seconds
#       Lorta Transfer Time: 0.000108 seconds
#       Lotr Transfer Time: 0.000396 seconds
#
#     Repetition 47/100
#       Lora Transfer Time: 0.001395 seconds
#       Lorta Transfer Time: 0.000134 seconds
#       Lotr Transfer Time: 0.000369 seconds
#
#     Repetition 48/100
#       Lora Transfer Time: 0.001388 seconds
#       Lorta Transfer Time: 0.000108 seconds
#       Lotr Transfer Time: 0.000396 seconds
#
#     Repetition 49/100
#       Lora Transfer Time: 0.001386 seconds
#       Lorta Transfer Time: 0.000111 seconds
#       Lotr Transfer Time: 0.000395 seconds
#
#     Repetition 50/100
#       Lora Transfer Time: 0.001390 seconds
#       Lorta Transfer Time: 0.000113 seconds
#       Lotr Transfer Time: 0.000392 seconds
#
#     Repetition 51/100
#       Lora Transfer Time: 0.001434 seconds
#       Lorta Transfer Time: 0.000110 seconds
#       Lotr Transfer Time: 0.000378 seconds
#
#     Repetition 52/100
#       Lora Transfer Time: 0.001384 seconds
#       Lorta Transfer Time: 0.000108 seconds
#       Lotr Transfer Time: 0.000395 seconds
#
#     Repetition 53/100
#       Lora Transfer Time: 0.001401 seconds
#       Lorta Transfer Time: 0.000109 seconds
#       Lotr Transfer Time: 0.000394 seconds
#
#     Repetition 54/100
#       Lora Transfer Time: 0.001387 seconds
#       Lorta Transfer Time: 0.000111 seconds
#       Lotr Transfer Time: 0.000391 seconds
#
#     Repetition 55/100
#       Lora Transfer Time: 0.001402 seconds
#       Lorta Transfer Time: 0.000109 seconds
#       Lotr Transfer Time: 0.000393 seconds
#
#     Repetition 56/100
#       Lora Transfer Time: 0.001382 seconds
#       Lorta Transfer Time: 0.000107 seconds
#       Lotr Transfer Time: 0.000396 seconds
#
#     Repetition 57/100
#       Lora Transfer Time: 0.001423 seconds
#       Lorta Transfer Time: 0.000107 seconds
#       Lotr Transfer Time: 0.000397 seconds
#
#     Repetition 58/100
#       Lora Transfer Time: 0.001380 seconds
#       Lorta Transfer Time: 0.000108 seconds
#       Lotr Transfer Time: 0.000382 seconds
#
#     Repetition 59/100
#       Lora Transfer Time: 0.001408 seconds
#       Lorta Transfer Time: 0.000109 seconds
#       Lotr Transfer Time: 0.000392 seconds
#
#     Repetition 60/100
#       Lora Transfer Time: 0.001388 seconds
#       Lorta Transfer Time: 0.000103 seconds
#       Lotr Transfer Time: 0.000399 seconds
#
#     Repetition 61/100
#       Lora Transfer Time: 0.001407 seconds
#       Lorta Transfer Time: 0.000110 seconds
#       Lotr Transfer Time: 0.000393 seconds
#
#     Repetition 62/100
#       Lora Transfer Time: 0.001387 seconds
#       Lorta Transfer Time: 0.000107 seconds
#       Lotr Transfer Time: 0.000397 seconds
#
#     Repetition 63/100
#       Lora Transfer Time: 0.001434 seconds
#       Lorta Transfer Time: 0.000112 seconds
#       Lotr Transfer Time: 0.000391 seconds
#
#     Repetition 64/100
#       Lora Transfer Time: 0.001388 seconds
#       Lorta Transfer Time: 0.000113 seconds
#       Lotr Transfer Time: 0.000388 seconds
#
#     Repetition 65/100
#       Lora Transfer Time: 0.001410 seconds
#       Lorta Transfer Time: 0.000111 seconds
#       Lotr Transfer Time: 0.000392 seconds
#
#     Repetition 66/100
#       Lora Transfer Time: 0.001388 seconds
#       Lorta Transfer Time: 0.000110 seconds
#       Lotr Transfer Time: 0.000378 seconds
#
#     Repetition 67/100
#       Lora Transfer Time: 0.001433 seconds
#       Lorta Transfer Time: 0.000109 seconds
#       Lotr Transfer Time: 0.000392 seconds
#
#     Repetition 68/100
#       Lora Transfer Time: 0.001386 seconds
#       Lorta Transfer Time: 0.000111 seconds
#       Lotr Transfer Time: 0.000393 seconds
#
#     Repetition 69/100
#       Lora Transfer Time: 0.001394 seconds
#       Lorta Transfer Time: 0.000110 seconds
#       Lotr Transfer Time: 0.000393 seconds
#
#     Repetition 70/100
#       Lora Transfer Time: 0.001390 seconds
#       Lorta Transfer Time: 0.000108 seconds
#       Lotr Transfer Time: 0.000374 seconds
#
#     Repetition 71/100
#       Lora Transfer Time: 0.001382 seconds
#       Lorta Transfer Time: 0.000111 seconds
#       Lotr Transfer Time: 0.000366 seconds
#
#     Repetition 72/100
#       Lora Transfer Time: 0.001387 seconds
#       Lorta Transfer Time: 0.000107 seconds
#       Lotr Transfer Time: 0.000376 seconds
#
#     Repetition 73/100
#       Lora Transfer Time: 0.001402 seconds
#       Lorta Transfer Time: 0.000109 seconds
#       Lotr Transfer Time: 0.000371 seconds
#
#     Repetition 74/100
#       Lora Transfer Time: 0.001389 seconds
#       Lorta Transfer Time: 0.000131 seconds
#       Lotr Transfer Time: 0.000350 seconds
#
#     Repetition 75/100
#       Lora Transfer Time: 0.001387 seconds
#       Lorta Transfer Time: 0.000107 seconds
#       Lotr Transfer Time: 0.000356 seconds
#
#     Repetition 76/100
#       Lora Transfer Time: 0.001394 seconds
#       Lorta Transfer Time: 0.000111 seconds
#       Lotr Transfer Time: 0.000365 seconds
#
#     Repetition 77/100
#       Lora Transfer Time: 0.001391 seconds
#       Lorta Transfer Time: 0.000105 seconds
#       Lotr Transfer Time: 0.000375 seconds
#
#     Repetition 78/100
#       Lora Transfer Time: 0.001379 seconds
#       Lorta Transfer Time: 0.000112 seconds
#       Lotr Transfer Time: 0.000368 seconds
#
#     Repetition 79/100
#       Lora Transfer Time: 0.001404 seconds
#       Lorta Transfer Time: 0.000110 seconds
#       Lotr Transfer Time: 0.000366 seconds
#
#     Repetition 80/100
#       Lora Transfer Time: 0.001410 seconds
#       Lorta Transfer Time: 0.000110 seconds
#       Lotr Transfer Time: 0.000368 seconds
#
#     Repetition 81/100
#       Lora Transfer Time: 0.001390 seconds
#       Lorta Transfer Time: 0.000106 seconds
#       Lotr Transfer Time: 0.000375 seconds
#
#     Repetition 82/100
#       Lora Transfer Time: 0.001431 seconds
#       Lorta Transfer Time: 0.000110 seconds
#       Lotr Transfer Time: 0.000369 seconds
#
#     Repetition 83/100
#       Lora Transfer Time: 0.001394 seconds
#       Lorta Transfer Time: 0.000113 seconds
#       Lotr Transfer Time: 0.000366 seconds
#
#     Repetition 84/100
#       Lora Transfer Time: 0.001408 seconds
#       Lorta Transfer Time: 0.000111 seconds
#       Lotr Transfer Time: 0.000368 seconds
#
#     Repetition 85/100
#       Lora Transfer Time: 0.001382 seconds
#       Lorta Transfer Time: 0.000107 seconds
#       Lotr Transfer Time: 0.000363 seconds
#
#     Repetition 86/100
#       Lora Transfer Time: 0.001402 seconds
#       Lorta Transfer Time: 0.000109 seconds
#       Lotr Transfer Time: 0.000369 seconds
#
#     Repetition 87/100
#       Lora Transfer Time: 0.001394 seconds
#       Lorta Transfer Time: 0.000107 seconds
#       Lotr Transfer Time: 0.000374 seconds
#
#     Repetition 88/100
#       Lora Transfer Time: 0.001427 seconds
#       Lorta Transfer Time: 0.000111 seconds
#       Lotr Transfer Time: 0.000368 seconds
#
#     Repetition 89/100
#       Lora Transfer Time: 0.001671 seconds
#       Lorta Transfer Time: 0.000375 seconds
#       Lotr Transfer Time: 0.000088 seconds
#
#     Repetition 90/100
#       Lora Transfer Time: 0.001412 seconds
#       Lorta Transfer Time: 0.000112 seconds
#       Lotr Transfer Time: 0.000371 seconds
#
#     Repetition 91/100
#       Lora Transfer Time: 0.001384 seconds
#       Lorta Transfer Time: 0.000106 seconds
#       Lotr Transfer Time: 0.000374 seconds
#
#     Repetition 92/100
#       Lora Transfer Time: 0.001417 seconds
#       Lorta Transfer Time: 0.000108 seconds
#       Lotr Transfer Time: 0.000372 seconds
#
#     Repetition 93/100
#       Lora Transfer Time: 0.001395 seconds
#       Lorta Transfer Time: 0.000108 seconds
#       Lotr Transfer Time: 0.000372 seconds
#
#     Repetition 94/100
#       Lora Transfer Time: 0.001435 seconds
#       Lorta Transfer Time: 0.000107 seconds
#       Lotr Transfer Time: 0.000375 seconds
#
#     Repetition 95/100
#       Lora Transfer Time: 0.001387 seconds
#       Lorta Transfer Time: 0.000110 seconds
#       Lotr Transfer Time: 0.000384 seconds
#
#     Repetition 96/100
#       Lora Transfer Time: 0.001393 seconds
#       Lorta Transfer Time: 0.000111 seconds
#       Lotr Transfer Time: 0.000371 seconds
#
#     Repetition 97/100
#       Lora Transfer Time: 0.001386 seconds
#       Lorta Transfer Time: 0.000113 seconds
#       Lotr Transfer Time: 0.000370 seconds
#
#     Repetition 98/100
#       Lora Transfer Time: 0.001395 seconds
#       Lorta Transfer Time: 0.000108 seconds
#       Lotr Transfer Time: 0.000372 seconds
#
#     Repetition 99/100
#       Lora Transfer Time: 0.001387 seconds
#       Lorta Transfer Time: 0.000108 seconds
#       Lotr Transfer Time: 0.000374 seconds
#
#     Repetition 100/100
#       Lora Transfer Time: 0.001400 seconds
#       Lorta Transfer Time: 0.000110 seconds
#       Lotr Transfer Time: 0.000371 seconds
#
#   Completed measurements for r=4, N=1.
#
# Testing with r=4 and N=10...
# Warming up GPU...
# Warm-up completed.
#
#   Starting transfer measurements for r=4, N=10...
#     Repetition 1/100
#       Lora Transfer Time: 0.012160 seconds
#       Lorta Transfer Time: 0.001066 seconds
#       Lotr Transfer Time: 0.003695 seconds
#
#     Repetition 2/100
#       Lora Transfer Time: 0.012399 seconds
#       Lorta Transfer Time: 0.001065 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 3/100
#       Lora Transfer Time: 0.012646 seconds
#       Lorta Transfer Time: 0.001066 seconds
#       Lotr Transfer Time: 0.003243 seconds
#
#     Repetition 4/100
#       Lora Transfer Time: 0.012648 seconds
#       Lorta Transfer Time: 0.001065 seconds
#       Lotr Transfer Time: 0.003244 seconds
#
#     Repetition 5/100
#       Lora Transfer Time: 0.012648 seconds
#       Lorta Transfer Time: 0.001064 seconds
#       Lotr Transfer Time: 0.003243 seconds
#
#     Repetition 6/100
#       Lora Transfer Time: 0.012605 seconds
#       Lorta Transfer Time: 0.001068 seconds
#       Lotr Transfer Time: 0.003243 seconds
#
#     Repetition 7/100
#       Lora Transfer Time: 0.012624 seconds
#       Lorta Transfer Time: 0.001069 seconds
#       Lotr Transfer Time: 0.003241 seconds
#
#     Repetition 8/100
#       Lora Transfer Time: 0.012642 seconds
#       Lorta Transfer Time: 0.001066 seconds
#       Lotr Transfer Time: 0.003244 seconds
#
#     Repetition 9/100
#       Lora Transfer Time: 0.012632 seconds
#       Lorta Transfer Time: 0.001074 seconds
#       Lotr Transfer Time: 0.003238 seconds
#
#     Repetition 10/100
#       Lora Transfer Time: 0.012628 seconds
#       Lorta Transfer Time: 0.001069 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 11/100
#       Lora Transfer Time: 0.012627 seconds
#       Lorta Transfer Time: 0.001067 seconds
#       Lotr Transfer Time: 0.003232 seconds
#
#     Repetition 12/100
#       Lora Transfer Time: 0.012639 seconds
#       Lorta Transfer Time: 0.001105 seconds
#       Lotr Transfer Time: 0.003205 seconds
#
#     Repetition 13/100
#       Lora Transfer Time: 0.012653 seconds
#       Lorta Transfer Time: 0.001069 seconds
#       Lotr Transfer Time: 0.003242 seconds
#
#     Repetition 14/100
#       Lora Transfer Time: 0.012628 seconds
#       Lorta Transfer Time: 0.001064 seconds
#       Lotr Transfer Time: 0.003246 seconds
#
#     Repetition 15/100
#       Lora Transfer Time: 0.012630 seconds
#       Lorta Transfer Time: 0.001082 seconds
#       Lotr Transfer Time: 0.003227 seconds
#
#     Repetition 16/100
#       Lora Transfer Time: 0.012632 seconds
#       Lorta Transfer Time: 0.001066 seconds
#       Lotr Transfer Time: 0.003246 seconds
#
#     Repetition 17/100
#       Lora Transfer Time: 0.012658 seconds
#       Lorta Transfer Time: 0.001066 seconds
#       Lotr Transfer Time: 0.003246 seconds
#
#     Repetition 18/100
#       Lora Transfer Time: 0.012643 seconds
#       Lorta Transfer Time: 0.001085 seconds
#       Lotr Transfer Time: 0.003226 seconds
#
#     Repetition 19/100
#       Lora Transfer Time: 0.012611 seconds
#       Lorta Transfer Time: 0.001068 seconds
#       Lotr Transfer Time: 0.003244 seconds
#
#     Repetition 20/100
#       Lora Transfer Time: 0.012650 seconds
#       Lorta Transfer Time: 0.001065 seconds
#       Lotr Transfer Time: 0.003246 seconds
#
#     Repetition 21/100
#       Lora Transfer Time: 0.012623 seconds
#       Lorta Transfer Time: 0.001066 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 22/100
#       Lora Transfer Time: 0.012638 seconds
#       Lorta Transfer Time: 0.001068 seconds
#       Lotr Transfer Time: 0.003243 seconds
#
#     Repetition 23/100
#       Lora Transfer Time: 0.012690 seconds
#       Lorta Transfer Time: 0.001025 seconds
#       Lotr Transfer Time: 0.003243 seconds
#
#     Repetition 24/100
#       Lora Transfer Time: 0.012660 seconds
#       Lorta Transfer Time: 0.001069 seconds
#       Lotr Transfer Time: 0.003241 seconds
#
#     Repetition 25/100
#       Lora Transfer Time: 0.012635 seconds
#       Lorta Transfer Time: 0.001063 seconds
#       Lotr Transfer Time: 0.003247 seconds
#
#     Repetition 26/100
#       Lora Transfer Time: 0.012666 seconds
#       Lorta Transfer Time: 0.001065 seconds
#       Lotr Transfer Time: 0.003246 seconds
#
#     Repetition 27/100
#       Lora Transfer Time: 0.012667 seconds
#       Lorta Transfer Time: 0.001066 seconds
#       Lotr Transfer Time: 0.003242 seconds
#
#     Repetition 28/100
#       Lora Transfer Time: 0.012623 seconds
#       Lorta Transfer Time: 0.001065 seconds
#       Lotr Transfer Time: 0.003243 seconds
#
#     Repetition 29/100
#       Lora Transfer Time: 0.012653 seconds
#       Lorta Transfer Time: 0.001064 seconds
#       Lotr Transfer Time: 0.003246 seconds
#
#     Repetition 30/100
#       Lora Transfer Time: 0.012634 seconds
#       Lorta Transfer Time: 0.001066 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 31/100
#       Lora Transfer Time: 0.012678 seconds
#       Lorta Transfer Time: 0.001068 seconds
#       Lotr Transfer Time: 0.003243 seconds
#
#     Repetition 32/100
#       Lora Transfer Time: 0.012603 seconds
#       Lorta Transfer Time: 0.001064 seconds
#       Lotr Transfer Time: 0.003243 seconds
#
#     Repetition 33/100
#       Lora Transfer Time: 0.012656 seconds
#       Lorta Transfer Time: 0.001068 seconds
#       Lotr Transfer Time: 0.003242 seconds
#
#     Repetition 34/100
#       Lora Transfer Time: 0.012614 seconds
#       Lorta Transfer Time: 0.001068 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 35/100
#       Lora Transfer Time: 0.012693 seconds
#       Lorta Transfer Time: 0.001024 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 36/100
#       Lora Transfer Time: 0.012648 seconds
#       Lorta Transfer Time: 0.001070 seconds
#       Lotr Transfer Time: 0.003242 seconds
#
#     Repetition 37/100
#       Lora Transfer Time: 0.012668 seconds
#       Lorta Transfer Time: 0.001064 seconds
#       Lotr Transfer Time: 0.003247 seconds
#
#     Repetition 38/100
#       Lora Transfer Time: 0.012629 seconds
#       Lorta Transfer Time: 0.001064 seconds
#       Lotr Transfer Time: 0.003246 seconds
#
#     Repetition 39/100
#       Lora Transfer Time: 0.012629 seconds
#       Lorta Transfer Time: 0.001064 seconds
#       Lotr Transfer Time: 0.003242 seconds
#
#     Repetition 40/100
#       Lora Transfer Time: 0.012654 seconds
#       Lorta Transfer Time: 0.001068 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 41/100
#       Lora Transfer Time: 0.012624 seconds
#       Lorta Transfer Time: 0.001067 seconds
#       Lotr Transfer Time: 0.003246 seconds
#
#     Repetition 42/100
#       Lora Transfer Time: 0.012671 seconds
#       Lorta Transfer Time: 0.001065 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 43/100
#       Lora Transfer Time: 0.012624 seconds
#       Lorta Transfer Time: 0.001066 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 44/100
#       Lora Transfer Time: 0.012621 seconds
#       Lorta Transfer Time: 0.001063 seconds
#       Lotr Transfer Time: 0.003246 seconds
#
#     Repetition 45/100
#       Lora Transfer Time: 0.012641 seconds
#       Lorta Transfer Time: 0.001065 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 46/100
#       Lora Transfer Time: 0.012614 seconds
#       Lorta Transfer Time: 0.001068 seconds
#       Lotr Transfer Time: 0.003244 seconds
#
#     Repetition 47/100
#       Lora Transfer Time: 0.012687 seconds
#       Lorta Transfer Time: 0.001023 seconds
#       Lotr Transfer Time: 0.003247 seconds
#
#     Repetition 48/100
#       Lora Transfer Time: 0.012652 seconds
#       Lorta Transfer Time: 0.001066 seconds
#       Lotr Transfer Time: 0.003242 seconds
#
#     Repetition 49/100
#       Lora Transfer Time: 0.012649 seconds
#       Lorta Transfer Time: 0.001065 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 50/100
#       Lora Transfer Time: 0.012651 seconds
#       Lorta Transfer Time: 0.001066 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 51/100
#       Lora Transfer Time: 0.012702 seconds
#       Lorta Transfer Time: 0.001067 seconds
#       Lotr Transfer Time: 0.003243 seconds
#
#     Repetition 52/100
#       Lora Transfer Time: 0.012628 seconds
#       Lorta Transfer Time: 0.001066 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 53/100
#       Lora Transfer Time: 0.012650 seconds
#       Lorta Transfer Time: 0.001066 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 54/100
#       Lora Transfer Time: 0.012606 seconds
#       Lorta Transfer Time: 0.001064 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 55/100
#       Lora Transfer Time: 0.012598 seconds
#       Lorta Transfer Time: 0.001064 seconds
#       Lotr Transfer Time: 0.003247 seconds
#
#     Repetition 56/100
#       Lora Transfer Time: 0.012616 seconds
#       Lorta Transfer Time: 0.001062 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 57/100
#       Lora Transfer Time: 0.012629 seconds
#       Lorta Transfer Time: 0.001063 seconds
#       Lotr Transfer Time: 0.003243 seconds
#
#     Repetition 58/100
#       Lora Transfer Time: 0.012621 seconds
#       Lorta Transfer Time: 0.001068 seconds
#       Lotr Transfer Time: 0.003246 seconds
#
#     Repetition 59/100
#       Lora Transfer Time: 0.012675 seconds
#       Lorta Transfer Time: 0.001017 seconds
#       Lotr Transfer Time: 0.003246 seconds
#
#     Repetition 60/100
#       Lora Transfer Time: 0.012670 seconds
#       Lorta Transfer Time: 0.001066 seconds
#       Lotr Transfer Time: 0.003243 seconds
#
#     Repetition 61/100
#       Lora Transfer Time: 0.012675 seconds
#       Lorta Transfer Time: 0.001065 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 62/100
#       Lora Transfer Time: 0.012655 seconds
#       Lorta Transfer Time: 0.001063 seconds
#       Lotr Transfer Time: 0.003247 seconds
#
#     Repetition 63/100
#       Lora Transfer Time: 0.012654 seconds
#       Lorta Transfer Time: 0.001065 seconds
#       Lotr Transfer Time: 0.003243 seconds
#
#     Repetition 64/100
#       Lora Transfer Time: 0.012668 seconds
#       Lorta Transfer Time: 0.001065 seconds
#       Lotr Transfer Time: 0.003246 seconds
#
#     Repetition 65/100
#       Lora Transfer Time: 0.012631 seconds
#       Lorta Transfer Time: 0.001065 seconds
#       Lotr Transfer Time: 0.003246 seconds
#
#     Repetition 66/100
#       Lora Transfer Time: 0.012645 seconds
#       Lorta Transfer Time: 0.001064 seconds
#       Lotr Transfer Time: 0.003243 seconds
#
#     Repetition 67/100
#       Lora Transfer Time: 0.012637 seconds
#       Lorta Transfer Time: 0.001066 seconds
#       Lotr Transfer Time: 0.003246 seconds
#
#     Repetition 68/100
#       Lora Transfer Time: 0.012671 seconds
#       Lorta Transfer Time: 0.001065 seconds
#       Lotr Transfer Time: 0.003247 seconds
#
#     Repetition 69/100
#       Lora Transfer Time: 0.012745 seconds
#       Lorta Transfer Time: 0.001065 seconds
#       Lotr Transfer Time: 0.003243 seconds
#
#     Repetition 70/100
#       Lora Transfer Time: 0.012629 seconds
#       Lorta Transfer Time: 0.001062 seconds
#       Lotr Transfer Time: 0.003246 seconds
#
#     Repetition 71/100
#       Lora Transfer Time: 0.012696 seconds
#       Lorta Transfer Time: 0.001024 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 72/100
#       Lora Transfer Time: 0.012668 seconds
#       Lorta Transfer Time: 0.001065 seconds
#       Lotr Transfer Time: 0.003246 seconds
#
#     Repetition 73/100
#       Lora Transfer Time: 0.012671 seconds
#       Lorta Transfer Time: 0.001062 seconds
#       Lotr Transfer Time: 0.003246 seconds
#
#     Repetition 74/100
#       Lora Transfer Time: 0.012636 seconds
#       Lorta Transfer Time: 0.001063 seconds
#       Lotr Transfer Time: 0.003246 seconds
#
#     Repetition 75/100
#       Lora Transfer Time: 0.012632 seconds
#       Lorta Transfer Time: 0.001064 seconds
#       Lotr Transfer Time: 0.003243 seconds
#
#     Repetition 76/100
#       Lora Transfer Time: 0.012631 seconds
#       Lorta Transfer Time: 0.001067 seconds
#       Lotr Transfer Time: 0.003243 seconds
#
#     Repetition 77/100
#       Lora Transfer Time: 0.012649 seconds
#       Lorta Transfer Time: 0.001064 seconds
#       Lotr Transfer Time: 0.003240 seconds
#
#     Repetition 78/100
#       Lora Transfer Time: 0.012659 seconds
#       Lorta Transfer Time: 0.001064 seconds
#       Lotr Transfer Time: 0.003242 seconds
#
#     Repetition 79/100
#       Lora Transfer Time: 0.012715 seconds
#       Lorta Transfer Time: 0.001066 seconds
#       Lotr Transfer Time: 0.003243 seconds
#
#     Repetition 80/100
#       Lora Transfer Time: 0.012634 seconds
#       Lorta Transfer Time: 0.001067 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 81/100
#       Lora Transfer Time: 0.012607 seconds
#       Lorta Transfer Time: 0.001064 seconds
#       Lotr Transfer Time: 0.003244 seconds
#
#     Repetition 82/100
#       Lora Transfer Time: 0.012659 seconds
#       Lorta Transfer Time: 0.001066 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 83/100
#       Lora Transfer Time: 0.012685 seconds
#       Lorta Transfer Time: 0.001023 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 84/100
#       Lora Transfer Time: 0.012652 seconds
#       Lorta Transfer Time: 0.001069 seconds
#       Lotr Transfer Time: 0.003241 seconds
#
#     Repetition 85/100
#       Lora Transfer Time: 0.012627 seconds
#       Lorta Transfer Time: 0.001065 seconds
#       Lotr Transfer Time: 0.003244 seconds
#
#     Repetition 86/100
#       Lora Transfer Time: 0.012656 seconds
#       Lorta Transfer Time: 0.001065 seconds
#       Lotr Transfer Time: 0.003246 seconds
#
#     Repetition 87/100
#       Lora Transfer Time: 0.012634 seconds
#       Lorta Transfer Time: 0.001065 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 88/100
#       Lora Transfer Time: 0.012650 seconds
#       Lorta Transfer Time: 0.001062 seconds
#       Lotr Transfer Time: 0.003247 seconds
#
#     Repetition 89/100
#       Lora Transfer Time: 0.012648 seconds
#       Lorta Transfer Time: 0.001066 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 90/100
#       Lora Transfer Time: 0.012659 seconds
#       Lorta Transfer Time: 0.001067 seconds
#       Lotr Transfer Time: 0.003244 seconds
#
#     Repetition 91/100
#       Lora Transfer Time: 0.012618 seconds
#       Lorta Transfer Time: 0.001066 seconds
#       Lotr Transfer Time: 0.003247 seconds
#
#     Repetition 92/100
#       Lora Transfer Time: 0.012649 seconds
#       Lorta Transfer Time: 0.001063 seconds
#       Lotr Transfer Time: 0.003246 seconds
#
#     Repetition 93/100
#       Lora Transfer Time: 0.012611 seconds
#       Lorta Transfer Time: 0.001068 seconds
#       Lotr Transfer Time: 0.003244 seconds
#
#     Repetition 94/100
#       Lora Transfer Time: 0.012643 seconds
#       Lorta Transfer Time: 0.001067 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 95/100
#       Lora Transfer Time: 0.012801 seconds
#       Lorta Transfer Time: 0.001014 seconds
#       Lotr Transfer Time: 0.003253 seconds
#
#     Repetition 96/100
#       Lora Transfer Time: 0.013089 seconds
#       Lorta Transfer Time: 0.001029 seconds
#       Lotr Transfer Time: 0.003245 seconds
#
#     Repetition 97/100
#       Lora Transfer Time: 0.012623 seconds
#       Lorta Transfer Time: 0.001063 seconds
#       Lotr Transfer Time: 0.003243 seconds
#
#     Repetition 98/100
#       Lora Transfer Time: 0.012672 seconds
#       Lorta Transfer Time: 0.001061 seconds
#       Lotr Transfer Time: 0.003246 seconds
#
#     Repetition 99/100
#       Lora Transfer Time: 0.012618 seconds
#       Lorta Transfer Time: 0.001063 seconds
#       Lotr Transfer Time: 0.003246 seconds
#
#     Repetition 100/100
#       Lora Transfer Time: 0.012659 seconds
#       Lorta Transfer Time: 0.001068 seconds
#       Lotr Transfer Time: 0.003243 seconds
#
#   Completed measurements for r=4, N=10.
#
# Testing with r=4 and N=100...
# Warming up GPU...
# Warm-up completed.
#
#   Starting transfer measurements for r=4, N=100...
#     Repetition 1/100
#       Lora Transfer Time: 0.127066 seconds
#       Lorta Transfer Time: 0.004455 seconds
#       Lotr Transfer Time: 0.017943 seconds
#
#     Repetition 2/100
#       Lora Transfer Time: 0.144137 seconds
#       Lorta Transfer Time: 0.004466 seconds
#       Lotr Transfer Time: 0.018137 seconds
#
#     Repetition 3/100
#       Lora Transfer Time: 0.144648 seconds
#       Lorta Transfer Time: 0.004427 seconds
#       Lotr Transfer Time: 0.017098 seconds
#
#     Repetition 4/100
#       Lora Transfer Time: 0.145556 seconds
#       Lorta Transfer Time: 0.005522 seconds
#       Lotr Transfer Time: 0.017092 seconds
#
#     Repetition 5/100
#       Lora Transfer Time: 0.144614 seconds
#       Lorta Transfer Time: 0.005484 seconds
#       Lotr Transfer Time: 0.017091 seconds
#
#     Repetition 6/100
#       Lora Transfer Time: 0.144723 seconds
#       Lorta Transfer Time: 0.005523 seconds
#       Lotr Transfer Time: 0.017094 seconds
#
#     Repetition 7/100
#       Lora Transfer Time: 0.144699 seconds
#       Lorta Transfer Time: 0.005488 seconds
#       Lotr Transfer Time: 0.017087 seconds
#
#     Repetition 8/100
#       Lora Transfer Time: 0.144602 seconds
#       Lorta Transfer Time: 0.005524 seconds
#       Lotr Transfer Time: 0.017092 seconds
#
#     Repetition 9/100
#       Lora Transfer Time: 0.144772 seconds
#       Lorta Transfer Time: 0.005483 seconds
#       Lotr Transfer Time: 0.017097 seconds
#
#     Repetition 10/100
#       Lora Transfer Time: 0.144663 seconds
#       Lorta Transfer Time: 0.005522 seconds
#       Lotr Transfer Time: 0.017092 seconds
#
#     Repetition 11/100
#       Lora Transfer Time: 0.144658 seconds
#       Lorta Transfer Time: 0.005481 seconds
#       Lotr Transfer Time: 0.017088 seconds
#
#     Repetition 12/100
#       Lora Transfer Time: 0.144581 seconds
#       Lorta Transfer Time: 0.005523 seconds
#       Lotr Transfer Time: 0.017092 seconds
#
#     Repetition 13/100
#       Lora Transfer Time: 0.144746 seconds
#       Lorta Transfer Time: 0.005481 seconds
#       Lotr Transfer Time: 0.018140 seconds
#
#     Repetition 14/100
#       Lora Transfer Time: 0.143600 seconds
#       Lorta Transfer Time: 0.005523 seconds
#       Lotr Transfer Time: 0.017091 seconds
#
#     Repetition 15/100
#       Lora Transfer Time: 0.144714 seconds
#       Lorta Transfer Time: 0.005484 seconds
#       Lotr Transfer Time: 0.017091 seconds
#
#     Repetition 16/100
#       Lora Transfer Time: 0.144657 seconds
#       Lorta Transfer Time: 0.005521 seconds
#       Lotr Transfer Time: 0.017092 seconds
#
#     Repetition 17/100
#       Lora Transfer Time: 0.144832 seconds
#       Lorta Transfer Time: 0.005482 seconds
#       Lotr Transfer Time: 0.017093 seconds
#
#     Repetition 18/100
#       Lora Transfer Time: 0.144643 seconds
#       Lorta Transfer Time: 0.005526 seconds
#       Lotr Transfer Time: 0.017089 seconds
#
#     Repetition 19/100
#       Lora Transfer Time: 0.144668 seconds
#       Lorta Transfer Time: 0.005482 seconds
#       Lotr Transfer Time: 0.017096 seconds
#
#     Repetition 20/100
#       Lora Transfer Time: 0.144691 seconds
#       Lorta Transfer Time: 0.005522 seconds
#       Lotr Transfer Time: 0.017090 seconds
#
#     Repetition 21/100
#       Lora Transfer Time: 0.144706 seconds
#       Lorta Transfer Time: 0.005482 seconds
#       Lotr Transfer Time: 0.017092 seconds
#
#     Repetition 22/100
#       Lora Transfer Time: 0.144652 seconds
#       Lorta Transfer Time: 0.005522 seconds
#       Lotr Transfer Time: 0.017087 seconds
#
#     Repetition 23/100
#       Lora Transfer Time: 0.144737 seconds
#       Lorta Transfer Time: 0.005484 seconds
#       Lotr Transfer Time: 0.017096 seconds
#
#     Repetition 24/100
#       Lora Transfer Time: 0.144568 seconds
#       Lorta Transfer Time: 0.005524 seconds
#       Lotr Transfer Time: 0.017087 seconds
#
#     Repetition 25/100
#       Lora Transfer Time: 0.144743 seconds
#       Lorta Transfer Time: 0.005475 seconds
#       Lotr Transfer Time: 0.017093 seconds
#
#     Repetition 26/100
#       Lora Transfer Time: 0.144595 seconds
#       Lorta Transfer Time: 0.005522 seconds
#       Lotr Transfer Time: 0.017087 seconds
#
#     Repetition 27/100
#       Lora Transfer Time: 0.144754 seconds
#       Lorta Transfer Time: 0.005487 seconds
#       Lotr Transfer Time: 0.017087 seconds
#
#     Repetition 28/100
#       Lora Transfer Time: 0.144616 seconds
#       Lorta Transfer Time: 0.005523 seconds
#       Lotr Transfer Time: 0.017093 seconds
#
#     Repetition 29/100
#       Lora Transfer Time: 0.144798 seconds
#       Lorta Transfer Time: 0.005482 seconds
#       Lotr Transfer Time: 0.017092 seconds
#
#     Repetition 30/100
#       Lora Transfer Time: 0.144494 seconds
#       Lorta Transfer Time: 0.005525 seconds
#       Lotr Transfer Time: 0.017092 seconds
#
#     Repetition 31/100
#       Lora Transfer Time: 0.144674 seconds
#       Lorta Transfer Time: 0.005482 seconds
#       Lotr Transfer Time: 0.017089 seconds
#
#     Repetition 32/100
#       Lora Transfer Time: 0.144634 seconds
#       Lorta Transfer Time: 0.005521 seconds
#       Lotr Transfer Time: 0.017093 seconds
#
#     Repetition 33/100
#       Lora Transfer Time: 0.144670 seconds
#       Lorta Transfer Time: 0.005482 seconds
#       Lotr Transfer Time: 0.017090 seconds
#
#     Repetition 34/100
#       Lora Transfer Time: 0.144565 seconds
#       Lorta Transfer Time: 0.005524 seconds
#       Lotr Transfer Time: 0.017089 seconds
#
#     Repetition 35/100
#       Lora Transfer Time: 0.144726 seconds
#       Lorta Transfer Time: 0.005481 seconds
#       Lotr Transfer Time: 0.017091 seconds
#
#     Repetition 36/100
#       Lora Transfer Time: 0.144642 seconds
#       Lorta Transfer Time: 0.005521 seconds
#       Lotr Transfer Time: 0.017090 seconds
#
#     Repetition 37/100
#       Lora Transfer Time: 0.144675 seconds
#       Lorta Transfer Time: 0.005487 seconds
#       Lotr Transfer Time: 0.017093 seconds
#
#     Repetition 38/100
#       Lora Transfer Time: 0.144615 seconds
#       Lorta Transfer Time: 0.005525 seconds
#       Lotr Transfer Time: 0.017094 seconds
#
#     Repetition 39/100
#       Lora Transfer Time: 0.144633 seconds
#       Lorta Transfer Time: 0.005480 seconds
#       Lotr Transfer Time: 0.017092 seconds
#
#     Repetition 40/100
#       Lora Transfer Time: 0.144548 seconds
#       Lorta Transfer Time: 0.005527 seconds
#       Lotr Transfer Time: 0.017090 seconds
#
#     Repetition 41/100
#       Lora Transfer Time: 0.144641 seconds
#       Lorta Transfer Time: 0.005484 seconds
#       Lotr Transfer Time: 0.017092 seconds
#
#     Repetition 42/100
#       Lora Transfer Time: 0.144614 seconds
#       Lorta Transfer Time: 0.005524 seconds
#       Lotr Transfer Time: 0.017092 seconds
#
#     Repetition 43/100
#       Lora Transfer Time: 0.144588 seconds
#       Lorta Transfer Time: 0.005481 seconds
#       Lotr Transfer Time: 0.017088 seconds
#
#     Repetition 44/100
#       Lora Transfer Time: 0.144500 seconds
#       Lorta Transfer Time: 0.005521 seconds
#       Lotr Transfer Time: 0.017088 seconds
#
#     Repetition 45/100
#       Lora Transfer Time: 0.144669 seconds
#       Lorta Transfer Time: 0.005481 seconds
#       Lotr Transfer Time: 0.017093 seconds
#
#     Repetition 46/100
#       Lora Transfer Time: 0.144542 seconds
#       Lorta Transfer Time: 0.005524 seconds
#       Lotr Transfer Time: 0.017089 seconds
#
#     Repetition 47/100
#       Lora Transfer Time: 0.144659 seconds
#       Lorta Transfer Time: 0.005482 seconds
#       Lotr Transfer Time: 0.017094 seconds
#
#     Repetition 48/100
#       Lora Transfer Time: 0.144620 seconds
#       Lorta Transfer Time: 0.005524 seconds
#       Lotr Transfer Time: 0.017090 seconds
#
#     Repetition 49/100
#       Lora Transfer Time: 0.144675 seconds
#       Lorta Transfer Time: 0.005480 seconds
#       Lotr Transfer Time: 0.017095 seconds
#
#     Repetition 50/100
#       Lora Transfer Time: 0.144550 seconds
#       Lorta Transfer Time: 0.005521 seconds
#       Lotr Transfer Time: 0.017085 seconds
#
#     Repetition 51/100
#       Lora Transfer Time: 0.144832 seconds
#       Lorta Transfer Time: 0.005483 seconds
#       Lotr Transfer Time: 0.017093 seconds
#
#     Repetition 52/100
#       Lora Transfer Time: 0.144630 seconds
#       Lorta Transfer Time: 0.005521 seconds
#       Lotr Transfer Time: 0.017097 seconds
#
#     Repetition 53/100
#       Lora Transfer Time: 0.144687 seconds
#       Lorta Transfer Time: 0.005480 seconds
#       Lotr Transfer Time: 0.017092 seconds
#
#     Repetition 54/100
#       Lora Transfer Time: 0.144482 seconds
#       Lorta Transfer Time: 0.005523 seconds
#       Lotr Transfer Time: 0.017092 seconds
#
#     Repetition 55/100
#       Lora Transfer Time: 0.144636 seconds
#       Lorta Transfer Time: 0.005486 seconds
#       Lotr Transfer Time: 0.017093 seconds
#
#     Repetition 56/100
#       Lora Transfer Time: 0.144463 seconds
#       Lorta Transfer Time: 0.005522 seconds
#       Lotr Transfer Time: 0.017089 seconds
#
#     Repetition 57/100
#       Lora Transfer Time: 0.144615 seconds
#       Lorta Transfer Time: 0.005484 seconds
#       Lotr Transfer Time: 0.017092 seconds
#
#     Repetition 58/100
#       Lora Transfer Time: 0.144493 seconds
#       Lorta Transfer Time: 0.005524 seconds
#       Lotr Transfer Time: 0.017097 seconds
#
#     Repetition 59/100
#       Lora Transfer Time: 0.144636 seconds
#       Lorta Transfer Time: 0.005483 seconds
#       Lotr Transfer Time: 0.017090 seconds
#
#     Repetition 60/100
#       Lora Transfer Time: 0.144562 seconds
#       Lorta Transfer Time: 0.005524 seconds
#       Lotr Transfer Time: 0.017090 seconds
#
#     Repetition 61/100
#       Lora Transfer Time: 0.144662 seconds
#       Lorta Transfer Time: 0.005484 seconds
#       Lotr Transfer Time: 0.017089 seconds
#
#     Repetition 62/100
#       Lora Transfer Time: 0.144507 seconds
#       Lorta Transfer Time: 0.005524 seconds
#       Lotr Transfer Time: 0.017091 seconds
#
#     Repetition 63/100
#       Lora Transfer Time: 0.144592 seconds
#       Lorta Transfer Time: 0.005481 seconds
#       Lotr Transfer Time: 0.017095 seconds
#
#     Repetition 64/100
#       Lora Transfer Time: 0.144493 seconds
#       Lorta Transfer Time: 0.005521 seconds
#       Lotr Transfer Time: 0.017092 seconds
#
#     Repetition 65/100
#       Lora Transfer Time: 0.144552 seconds
#       Lorta Transfer Time: 0.005484 seconds
#       Lotr Transfer Time: 0.017089 seconds
#
#     Repetition 66/100
#       Lora Transfer Time: 0.144439 seconds
#       Lorta Transfer Time: 0.005526 seconds
#       Lotr Transfer Time: 0.017091 seconds
#
#     Repetition 67/100
#       Lora Transfer Time: 0.144605 seconds
#       Lorta Transfer Time: 0.005483 seconds
#       Lotr Transfer Time: 0.017101 seconds
#
#     Repetition 68/100
#       Lora Transfer Time: 0.144544 seconds
#       Lorta Transfer Time: 0.005523 seconds
#       Lotr Transfer Time: 0.017091 seconds
#
#     Repetition 69/100
#       Lora Transfer Time: 0.144634 seconds
#       Lorta Transfer Time: 0.005481 seconds
#       Lotr Transfer Time: 0.017090 seconds
#
#     Repetition 70/100
#       Lora Transfer Time: 0.144555 seconds
#       Lorta Transfer Time: 0.005524 seconds
#       Lotr Transfer Time: 0.017092 seconds
#
#     Repetition 71/100
#       Lora Transfer Time: 0.144598 seconds
#       Lorta Transfer Time: 0.005480 seconds
#       Lotr Transfer Time: 0.017102 seconds
#
#     Repetition 72/100
#       Lora Transfer Time: 0.144562 seconds
#       Lorta Transfer Time: 0.005523 seconds
#       Lotr Transfer Time: 0.017092 seconds
#
#     Repetition 73/100
#       Lora Transfer Time: 0.144556 seconds
#       Lorta Transfer Time: 0.005485 seconds
#       Lotr Transfer Time: 0.017086 seconds
#
#     Repetition 74/100
#       Lora Transfer Time: 0.144459 seconds
#       Lorta Transfer Time: 0.005521 seconds
#       Lotr Transfer Time: 0.017099 seconds
#
#     Repetition 75/100
#       Lora Transfer Time: 0.144621 seconds
#       Lorta Transfer Time: 0.005483 seconds
#       Lotr Transfer Time: 0.017092 seconds
#
#     Repetition 76/100
#       Lora Transfer Time: 0.144615 seconds
#       Lorta Transfer Time: 0.005522 seconds
#       Lotr Transfer Time: 0.017092 seconds
#
#     Repetition 77/100
#       Lora Transfer Time: 0.144592 seconds
#       Lorta Transfer Time: 0.005485 seconds
#       Lotr Transfer Time: 0.017096 seconds
#
#     Repetition 78/100
#       Lora Transfer Time: 0.144500 seconds
#       Lorta Transfer Time: 0.005524 seconds
#       Lotr Transfer Time: 0.017090 seconds
#
#     Repetition 79/100
#       Lora Transfer Time: 0.144696 seconds
#       Lorta Transfer Time: 0.005482 seconds
#       Lotr Transfer Time: 0.017090 seconds
#
#     Repetition 80/100
#       Lora Transfer Time: 0.144502 seconds
#       Lorta Transfer Time: 0.005522 seconds
#       Lotr Transfer Time: 0.017091 seconds
#
#     Repetition 81/100
#       Lora Transfer Time: 0.144592 seconds
#       Lorta Transfer Time: 0.005485 seconds
#       Lotr Transfer Time: 0.017086 seconds
#
#     Repetition 82/100
#       Lora Transfer Time: 0.144511 seconds
#       Lorta Transfer Time: 0.005522 seconds
#       Lotr Transfer Time: 0.017094 seconds
#
#     Repetition 83/100
#       Lora Transfer Time: 0.144506 seconds
#       Lorta Transfer Time: 0.005484 seconds
#       Lotr Transfer Time: 0.017098 seconds
#
#     Repetition 84/100
#       Lora Transfer Time: 0.144630 seconds
#       Lorta Transfer Time: 0.005522 seconds
#       Lotr Transfer Time: 0.017090 seconds
#
#     Repetition 85/100
#       Lora Transfer Time: 0.144676 seconds
#       Lorta Transfer Time: 0.005484 seconds
#       Lotr Transfer Time: 0.017092 seconds
#
#     Repetition 86/100
#       Lora Transfer Time: 0.144526 seconds
#       Lorta Transfer Time: 0.005524 seconds
#       Lotr Transfer Time: 0.017087 seconds
#
#     Repetition 87/100
#       Lora Transfer Time: 0.144656 seconds
#       Lorta Transfer Time: 0.005485 seconds
#       Lotr Transfer Time: 0.017095 seconds
#
#     Repetition 88/100
#       Lora Transfer Time: 0.144486 seconds
#       Lorta Transfer Time: 0.005522 seconds
#       Lotr Transfer Time: 0.017105 seconds
#
#     Repetition 89/100
#       Lora Transfer Time: 0.144581 seconds
#       Lorta Transfer Time: 0.005483 seconds
#       Lotr Transfer Time: 0.017087 seconds
#
#     Repetition 90/100
#       Lora Transfer Time: 0.144516 seconds
#       Lorta Transfer Time: 0.005526 seconds
#       Lotr Transfer Time: 0.017089 seconds
#
#     Repetition 91/100
#       Lora Transfer Time: 0.144680 seconds
#       Lorta Transfer Time: 0.005477 seconds
#       Lotr Transfer Time: 0.017088 seconds
#
#     Repetition 92/100
#       Lora Transfer Time: 0.144584 seconds
#       Lorta Transfer Time: 0.005522 seconds
#       Lotr Transfer Time: 0.017094 seconds
#
#     Repetition 93/100
#       Lora Transfer Time: 0.144655 seconds
#       Lorta Transfer Time: 0.005485 seconds
#       Lotr Transfer Time: 0.017106 seconds
#
#     Repetition 94/100
#       Lora Transfer Time: 0.144562 seconds
#       Lorta Transfer Time: 0.005525 seconds
#       Lotr Transfer Time: 0.017088 seconds
#
#     Repetition 95/100
#       Lora Transfer Time: 0.144522 seconds
#       Lorta Transfer Time: 0.005481 seconds
#       Lotr Transfer Time: 0.017091 seconds
#
#     Repetition 96/100
#       Lora Transfer Time: 0.144523 seconds
#       Lorta Transfer Time: 0.005524 seconds
#       Lotr Transfer Time: 0.017087 seconds
#
#     Repetition 97/100
#       Lora Transfer Time: 0.144707 seconds
#       Lorta Transfer Time: 0.005480 seconds
#       Lotr Transfer Time: 0.017090 seconds
#
#     Repetition 98/100
#       Lora Transfer Time: 0.144476 seconds
#       Lorta Transfer Time: 0.005521 seconds
#       Lotr Transfer Time: 0.017092 seconds
#
#     Repetition 99/100
#       Lora Transfer Time: 0.144668 seconds
#       Lorta Transfer Time: 0.005481 seconds
#       Lotr Transfer Time: 0.017089 seconds
#
#     Repetition 100/100
#       Lora Transfer Time: 0.144657 seconds
#       Lorta Transfer Time: 0.005524 seconds
#       Lotr Transfer Time: 0.017092 seconds
#
#   Completed measurements for r=4, N=100.
#
# Testing with r=64 and N=1...
# Warming up GPU...
# Warm-up completed.
#
#   Starting transfer measurements for r=64, N=1...
#     Repetition 1/100
#       Lora Transfer Time: 0.076679 seconds
#       Lorta Transfer Time: 0.001125 seconds
#       Lotr Transfer Time: 0.004634 seconds
#
#     Repetition 2/100
#       Lora Transfer Time: 0.021564 seconds
#       Lorta Transfer Time: 0.001084 seconds
#       Lotr Transfer Time: 0.003480 seconds
#
#     Repetition 3/100
#       Lora Transfer Time: 0.022613 seconds
#       Lorta Transfer Time: 0.001079 seconds
#       Lotr Transfer Time: 0.003404 seconds
#
#     Repetition 4/100
#       Lora Transfer Time: 0.022219 seconds
#       Lorta Transfer Time: 0.001081 seconds
#       Lotr Transfer Time: 0.003404 seconds
#
#     Repetition 5/100
#       Lora Transfer Time: 0.022300 seconds
#       Lorta Transfer Time: 0.001046 seconds
#       Lotr Transfer Time: 0.003404 seconds
#
#     Repetition 6/100
#       Lora Transfer Time: 0.022273 seconds
#       Lorta Transfer Time: 0.001082 seconds
#       Lotr Transfer Time: 0.003404 seconds
#
#     Repetition 7/100
#       Lora Transfer Time: 0.022224 seconds
#       Lorta Transfer Time: 0.001082 seconds
#       Lotr Transfer Time: 0.003403 seconds
#
#     Repetition 8/100
#       Lora Transfer Time: 0.022266 seconds
#       Lorta Transfer Time: 0.001081 seconds
#       Lotr Transfer Time: 0.003405 seconds
#
#     Repetition 9/100
#       Lora Transfer Time: 0.022246 seconds
#       Lorta Transfer Time: 0.001083 seconds
#       Lotr Transfer Time: 0.003401 seconds
#
#     Repetition 10/100
#       Lora Transfer Time: 0.022198 seconds
#       Lorta Transfer Time: 0.001082 seconds
#       Lotr Transfer Time: 0.003405 seconds
#
# ...
#       Lorta Transfer Time: 0.061507 seconds
#       Lotr Transfer Time: 0.374739 seconds
#
#     Repetition 7/100
#       Lora Transfer Time: 2.258493 seconds
#       Lorta Transfer Time: 0.061458 seconds
#       Lotr Transfer Time: 0.375055 seconds
#
#     Repetition 8/100
#       Lora Transfer Time: 2.263310 seconds
#       Lorta Transfer Time: 0.061449 seconds
#       Lotr Transfer Time: 0.375172 seconds
#
#     Repetition 9/100
#       Lora Transfer Time: 2.260748 seconds
#       Lorta Transfer Time: 0.061553 seconds
#       Lotr Transfer Time: 0.374892 seconds
#
#     Repetition 10/100
#       Lora Transfer Time: 2.238237 seconds
#       Lorta Transfer Time: 0.061511 seconds
#       Lotr Transfer Time: 0.375050 seconds
#
#     Repetition 11/100
#       Lora Transfer Time: 2.276566 seconds
#       Lorta Transfer Time: 0.061481 seconds
#       Lotr Transfer Time: 0.375059 seconds
#
#     Repetition 12/100
#       Lora Transfer Time: 2.273012 seconds
#       Lorta Transfer Time: 0.061537 seconds
#       Lotr Transfer Time: 0.375076 seconds
#
#     Repetition 13/100
#       Lora Transfer Time: 2.257436 seconds
#       Lorta Transfer Time: 0.061475 seconds
#       Lotr Transfer Time: 0.375104 seconds
#
#     Repetition 14/100
#       Lora Transfer Time: 2.260386 seconds
#       Lorta Transfer Time: 0.061538 seconds
#       Lotr Transfer Time: 0.375024 seconds
#
#     Repetition 15/100
#       Lora Transfer Time: 2.259617 seconds
#       Lorta Transfer Time: 0.061454 seconds
#       Lotr Transfer Time: 0.375090 seconds
#
#     Repetition 16/100
#       Lora Transfer Time: 2.285233 seconds
#       Lorta Transfer Time: 0.061443 seconds
#       Lotr Transfer Time: 0.375116 seconds
#
#     Repetition 17/100
#       Lora Transfer Time: 2.287497 seconds
#       Lorta Transfer Time: 0.061567 seconds
#       Lotr Transfer Time: 0.374905 seconds
#
#     Repetition 18/100
#       Lora Transfer Time: 2.272583 seconds
#       Lorta Transfer Time: 0.061408 seconds
#       Lotr Transfer Time: 0.374940 seconds
#
#     Repetition 19/100
#       Lora Transfer Time: 2.275565 seconds
#       Lorta Transfer Time: 0.061512 seconds
#       Lotr Transfer Time: 0.374962 seconds
#
#     Repetition 20/100
#       Lora Transfer Time: 2.275478 seconds
#       Lorta Transfer Time: 0.061468 seconds
#       Lotr Transfer Time: 0.375053 seconds
#
#     Repetition 21/100
#       Lora Transfer Time: 2.286128 seconds
#       Lorta Transfer Time: 0.061493 seconds
#       Lotr Transfer Time: 0.375153 seconds
#
#     Repetition 22/100
#       Lora Transfer Time: 2.285356 seconds
#       Lorta Transfer Time: 0.061531 seconds
#       Lotr Transfer Time: 0.374876 seconds
#
#     Repetition 23/100
#       Lora Transfer Time: 2.273655 seconds
#       Lorta Transfer Time: 0.061460 seconds
#       Lotr Transfer Time: 0.374978 seconds
#
#     Repetition 24/100
#       Lora Transfer Time: 2.274751 seconds
#       Lorta Transfer Time: 0.061492 seconds
#       Lotr Transfer Time: 0.375152 seconds
#
#     Repetition 25/100
#       Lora Transfer Time: 2.274023 seconds
#       Lorta Transfer Time: 0.061518 seconds
#       Lotr Transfer Time: 0.374963 seconds
#
#     Repetition 26/100
#       Lora Transfer Time: 2.262199 seconds
#       Lorta Transfer Time: 0.061479 seconds
#       Lotr Transfer Time: 0.375104 seconds
#
#     Repetition 27/100
#       Lora Transfer Time: 2.257725 seconds
#       Lorta Transfer Time: 0.061517 seconds
#       Lotr Transfer Time: 0.375092 seconds
#
#     Repetition 28/100
#       Lora Transfer Time: 2.258140 seconds
#       Lorta Transfer Time: 0.061441 seconds
#       Lotr Transfer Time: 0.375046 seconds
#
#     Repetition 29/100
#       Lora Transfer Time: 2.260499 seconds
#       Lorta Transfer Time: 0.061469 seconds
#       Lotr Transfer Time: 0.375107 seconds
#
#     Repetition 30/100
#       Lora Transfer Time: 2.265386 seconds
#       Lorta Transfer Time: 0.061538 seconds
#       Lotr Transfer Time: 0.375047 seconds
#
#     Repetition 31/100
#       Lora Transfer Time: 2.265685 seconds
#       Lorta Transfer Time: 0.061424 seconds
#       Lotr Transfer Time: 0.375016 seconds
#
#     Repetition 32/100
#       Lora Transfer Time: 2.262621 seconds
#       Lorta Transfer Time: 0.061465 seconds
#       Lotr Transfer Time: 0.374918 seconds
#
#     Repetition 33/100
#       Lora Transfer Time: 2.262160 seconds
#       Lorta Transfer Time: 0.061538 seconds
#       Lotr Transfer Time: 0.375048 seconds
#
#     Repetition 34/100
#       Lora Transfer Time: 2.264516 seconds
#       Lorta Transfer Time: 0.061431 seconds
#       Lotr Transfer Time: 0.375012 seconds
#
#     Repetition 35/100
#       Lora Transfer Time: 2.288502 seconds
#       Lorta Transfer Time: 0.061515 seconds
#       Lotr Transfer Time: 0.375041 seconds
#
#     Repetition 36/100
#       Lora Transfer Time: 2.275711 seconds
#       Lorta Transfer Time: 0.061362 seconds
#       Lotr Transfer Time: 0.375146 seconds
#
#     Repetition 37/100
#       Lora Transfer Time: 2.278297 seconds
#       Lorta Transfer Time: 0.061470 seconds
#       Lotr Transfer Time: 0.375070 seconds
#
#     Repetition 38/100
#       Lora Transfer Time: 2.278883 seconds
#       Lorta Transfer Time: 0.061518 seconds
#       Lotr Transfer Time: 0.374752 seconds
#
#     Repetition 39/100
#       Lora Transfer Time: 2.281946 seconds
#       Lorta Transfer Time: 0.061446 seconds
#       Lotr Transfer Time: 0.375160 seconds
#
#     Repetition 40/100
#       Lora Transfer Time: 2.256567 seconds
#       Lorta Transfer Time: 0.061515 seconds
#       Lotr Transfer Time: 0.375107 seconds
#
#     Repetition 41/100
#       Lora Transfer Time: 2.257326 seconds
#       Lorta Transfer Time: 0.061452 seconds
#       Lotr Transfer Time: 0.375128 seconds
#
#     Repetition 42/100
#       Lora Transfer Time: 2.256816 seconds
#       Lorta Transfer Time: 0.061391 seconds
#       Lotr Transfer Time: 0.375006 seconds
#
#     Repetition 43/100
#       Lora Transfer Time: 2.253777 seconds
#       Lorta Transfer Time: 0.061495 seconds
#       Lotr Transfer Time: 0.376062 seconds
#
#     Repetition 44/100
#       Lora Transfer Time: 2.248697 seconds
#       Lorta Transfer Time: 0.061413 seconds
#       Lotr Transfer Time: 0.374952 seconds
#
#     Repetition 45/100
#       Lora Transfer Time: 2.256981 seconds
#       Lorta Transfer Time: 0.061501 seconds
#       Lotr Transfer Time: 0.375206 seconds
#
#     Repetition 46/100
#       Lora Transfer Time: 2.277328 seconds
#       Lorta Transfer Time: 0.061525 seconds
#       Lotr Transfer Time: 0.375051 seconds
#
#     Repetition 47/100
#       Lora Transfer Time: 2.280993 seconds
#       Lorta Transfer Time: 0.061424 seconds
#       Lotr Transfer Time: 0.375046 seconds
#
#     Repetition 48/100
#       Lora Transfer Time: 2.295827 seconds
#       Lorta Transfer Time: 0.061539 seconds
#       Lotr Transfer Time: 0.374980 seconds
#
#     Repetition 49/100
#       Lora Transfer Time: 2.288003 seconds
#       Lorta Transfer Time: 0.061467 seconds
#       Lotr Transfer Time: 0.375050 seconds
#
#     Repetition 50/100
#       Lora Transfer Time: 2.280123 seconds
#       Lorta Transfer Time: 0.061522 seconds
#       Lotr Transfer Time: 0.375152 seconds
#
#     Repetition 51/100
#       Lora Transfer Time: 2.271499 seconds
#       Lorta Transfer Time: 0.061578 seconds
#       Lotr Transfer Time: 0.374955 seconds
#
#     Repetition 52/100
#       Lora Transfer Time: 2.280996 seconds
#       Lorta Transfer Time: 0.061430 seconds
#       Lotr Transfer Time: 0.374991 seconds
#
#     Repetition 53/100
#       Lora Transfer Time: 2.272578 seconds
#       Lorta Transfer Time: 0.061459 seconds
#       Lotr Transfer Time: 0.374994 seconds
#
#     Repetition 54/100
#       Lora Transfer Time: 2.280796 seconds
#       Lorta Transfer Time: 0.061522 seconds
#       Lotr Transfer Time: 0.375029 seconds
#
#     Repetition 55/100
#       Lora Transfer Time: 2.277989 seconds
#       Lorta Transfer Time: 0.061466 seconds
#       Lotr Transfer Time: 0.375141 seconds
#
#     Repetition 56/100
#       Lora Transfer Time: 2.280326 seconds
#       Lorta Transfer Time: 0.061554 seconds
#       Lotr Transfer Time: 0.376055 seconds
#
#     Repetition 57/100
#       Lora Transfer Time: 2.294266 seconds
#       Lorta Transfer Time: 0.061433 seconds
#       Lotr Transfer Time: 0.375139 seconds
#
#     Repetition 58/100
#       Lora Transfer Time: 2.276572 seconds
#       Lorta Transfer Time: 0.061450 seconds
#       Lotr Transfer Time: 0.375045 seconds
#
#     Repetition 59/100
#       Lora Transfer Time: 2.279409 seconds
#       Lorta Transfer Time: 0.061579 seconds
#       Lotr Transfer Time: 0.374978 seconds
#
#     Repetition 60/100
#       Lora Transfer Time: 2.289107 seconds
#       Lorta Transfer Time: 0.061456 seconds
#       Lotr Transfer Time: 0.375010 seconds
#
#     Repetition 61/100
#       Lora Transfer Time: 2.279883 seconds
#       Lorta Transfer Time: 0.061501 seconds
#       Lotr Transfer Time: 0.375140 seconds
#
#     Repetition 62/100
#       Lora Transfer Time: 2.288929 seconds
#       Lorta Transfer Time: 0.061492 seconds
#       Lotr Transfer Time: 0.375055 seconds
#
#     Repetition 63/100
#       Lora Transfer Time: 2.290207 seconds
#       Lorta Transfer Time: 0.061463 seconds
#       Lotr Transfer Time: 0.375103 seconds
#
#     Repetition 64/100
#       Lora Transfer Time: 2.278945 seconds
#       Lorta Transfer Time: 0.061471 seconds
#       Lotr Transfer Time: 0.375042 seconds
#
#     Repetition 65/100
#       Lora Transfer Time: 2.289928 seconds
#       Lorta Transfer Time: 0.061490 seconds
#       Lotr Transfer Time: 0.375104 seconds
#
#     Repetition 66/100
#       Lora Transfer Time: 2.279129 seconds
#       Lorta Transfer Time: 0.061378 seconds
#       Lotr Transfer Time: 0.374979 seconds
#
#     Repetition 67/100
#       Lora Transfer Time: 2.282294 seconds
#       Lorta Transfer Time: 0.061541 seconds
#       Lotr Transfer Time: 0.374998 seconds
#
#     Repetition 68/100
#       Lora Transfer Time: 2.292113 seconds
#       Lorta Transfer Time: 0.061453 seconds
#       Lotr Transfer Time: 0.375988 seconds
#
#     Repetition 69/100
#       Lora Transfer Time: 2.280049 seconds
#       Lorta Transfer Time: 0.061450 seconds
#       Lotr Transfer Time: 0.375043 seconds
#
#     Repetition 70/100
#       Lora Transfer Time: 2.283599 seconds
#       Lorta Transfer Time: 0.061500 seconds
#       Lotr Transfer Time: 0.375037 seconds
#
#     Repetition 71/100
#       Lora Transfer Time: 2.281300 seconds
#       Lorta Transfer Time: 0.061498 seconds
#       Lotr Transfer Time: 0.375002 seconds
#
#     Repetition 72/100
#       Lora Transfer Time: 2.282649 seconds
#       Lorta Transfer Time: 0.061525 seconds
#       Lotr Transfer Time: 0.374916 seconds
#
#     Repetition 73/100
#       Lora Transfer Time: 2.278816 seconds
#       Lorta Transfer Time: 0.061493 seconds
#       Lotr Transfer Time: 0.375164 seconds
#
#     Repetition 74/100
#       Lora Transfer Time: 2.279294 seconds
#       Lorta Transfer Time: 0.061509 seconds
#       Lotr Transfer Time: 0.375151 seconds
#
#     Repetition 75/100
#       Lora Transfer Time: 2.280575 seconds
#       Lorta Transfer Time: 0.061571 seconds
#       Lotr Transfer Time: 0.374946 seconds
#
#     Repetition 76/100
#       Lora Transfer Time: 2.284261 seconds
#       Lorta Transfer Time: 0.061495 seconds
#       Lotr Transfer Time: 0.375161 seconds
#
#     Repetition 77/100
#       Lora Transfer Time: 2.276654 seconds
#       Lorta Transfer Time: 0.061426 seconds
#       Lotr Transfer Time: 0.375015 seconds
#
#     Repetition 78/100
#       Lora Transfer Time: 2.278134 seconds
#       Lorta Transfer Time: 0.061614 seconds
#       Lotr Transfer Time: 0.374752 seconds
#
#     Repetition 79/100
#       Lora Transfer Time: 2.275878 seconds
#       Lorta Transfer Time: 0.061409 seconds
#       Lotr Transfer Time: 0.375155 seconds
#
#     Repetition 80/100
#       Lora Transfer Time: 2.283558 seconds
#       Lorta Transfer Time: 0.061495 seconds
#       Lotr Transfer Time: 0.375043 seconds
#
#     Repetition 81/100
#       Lora Transfer Time: 2.268838 seconds
#       Lorta Transfer Time: 0.061409 seconds
#       Lotr Transfer Time: 0.375015 seconds
#
#     Repetition 82/100
#       Lora Transfer Time: 2.279987 seconds
#       Lorta Transfer Time: 0.061488 seconds
#       Lotr Transfer Time: 0.375164 seconds
#
#     Repetition 83/100
#       Lora Transfer Time: 2.276010 seconds
#       Lorta Transfer Time: 0.061495 seconds
#       Lotr Transfer Time: 0.374964 seconds
#
#     Repetition 84/100
#       Lora Transfer Time: 2.297794 seconds
#       Lorta Transfer Time: 0.061458 seconds
#       Lotr Transfer Time: 0.375069 seconds
#
#     Repetition 85/100
#       Lora Transfer Time: 2.277672 seconds
#       Lorta Transfer Time: 0.061459 seconds
#       Lotr Transfer Time: 0.375110 seconds
#
#     Repetition 86/100
#       Lora Transfer Time: 2.271831 seconds
#       Lorta Transfer Time: 0.061545 seconds
#       Lotr Transfer Time: 0.375107 seconds
#
#     Repetition 87/100
#       Lora Transfer Time: 2.281927 seconds
#       Lorta Transfer Time: 0.061440 seconds
#       Lotr Transfer Time: 0.374964 seconds
#
#     Repetition 88/100
#       Lora Transfer Time: 2.274909 seconds
#       Lorta Transfer Time: 0.061514 seconds
#       Lotr Transfer Time: 0.374951 seconds
#
#     Repetition 89/100
#       Lora Transfer Time: 2.303241 seconds
#       Lorta Transfer Time: 0.061391 seconds
#       Lotr Transfer Time: 0.375005 seconds
#
#     Repetition 90/100
#       Lora Transfer Time: 2.276903 seconds
#       Lorta Transfer Time: 0.061461 seconds
#       Lotr Transfer Time: 0.375146 seconds
#
#     Repetition 91/100
#       Lora Transfer Time: 2.275605 seconds
#       Lorta Transfer Time: 0.061558 seconds
#       Lotr Transfer Time: 0.375032 seconds
#
#     Repetition 92/100
#       Lora Transfer Time: 2.290531 seconds
#       Lorta Transfer Time: 0.061494 seconds
#       Lotr Transfer Time: 0.375184 seconds
#
#     Repetition 93/100
#       Lora Transfer Time: 2.279023 seconds
#       Lorta Transfer Time: 0.061528 seconds
#       Lotr Transfer Time: 0.375044 seconds
#
#     Repetition 94/100
#       Lora Transfer Time: 2.268945 seconds
#       Lorta Transfer Time: 0.061426 seconds
#       Lotr Transfer Time: 0.374988 seconds
#
#     Repetition 95/100
#       Lora Transfer Time: 2.279686 seconds
#       Lorta Transfer Time: 0.061402 seconds
#       Lotr Transfer Time: 0.375136 seconds
#
#     Repetition 96/100
#       Lora Transfer Time: 2.294067 seconds
#       Lorta Transfer Time: 0.061524 seconds
#       Lotr Transfer Time: 0.374944 seconds
#
#     Repetition 97/100
#       Lora Transfer Time: 2.273924 seconds
#       Lorta Transfer Time: 0.061435 seconds
#       Lotr Transfer Time: 0.375124 seconds
#
#     Repetition 98/100
#       Lora Transfer Time: 2.277810 seconds
#       Lorta Transfer Time: 0.061303 seconds
#       Lotr Transfer Time: 0.375136 seconds
#
#     Repetition 99/100
#       Lora Transfer Time: 2.269999 seconds
#       Lorta Transfer Time: 0.061550 seconds
#       Lotr Transfer Time: 0.375072 seconds
#
#     Repetition 100/100
#       Lora Transfer Time: 2.276209 seconds
#       Lorta Transfer Time: 0.061427 seconds
#       Lotr Transfer Time: 0.375089 seconds
#
#   Completed measurements for r=64, N=100.
#
# Transfer Time Comparison Results:
#    Rank (r)  Repetitions (N)  Lora_Average_Transfer_Time (s)  \
# 0         4                1                        0.010464
# 1         4               10                        0.012645
# 2         4              100                        0.144434
# 3        64                1                        0.022806
# 4        64               10                        0.215736
# 5        64              100                        2.272057
#
#    Lora_Std_Dev (s)  Lorta_Average_Transfer_Time (s)  Lorta_Std_Dev (s)  \
# 0          0.088758                         0.000115           0.000034
# 1          0.000076                         0.001063           0.000013
# 2          0.001754                         0.005471           0.000181
# 3          0.005421                         0.001077           0.000014
# 4          0.001659                         0.008811           0.000005
# 5          0.030548                         0.061495           0.000147
#
#    Lotr_Average_Transfer_Time (s)  Lotr_Std_Dev (s)
# 0                        0.000415          0.000243
# 1                        0.003248          0.000045
# 2                        0.017121          0.000168
# 3                        0.003437          0.000190
# 4                        0.041022          0.000039
# 5                        0.375066          0.000195
# Results have been saved to 'gpu_transfer_times_enhanced_with_lotr.csv'.

# %%
df = results_df
# Convert seconds to milliseconds (1s = 1000ms)
df["Lora_Average_Transfer_Time (ms)"] = df["Lora_Average_Transfer_Time (s)"] * 1000
df["Lora_Std_Dev (ms)"] = df["Lora_Std_Dev (s)"] * 1000
df["Lorta_Average_Transfer_Time (ms)"] = df["Lorta_Average_Transfer_Time (s)"] * 1000
df["Lorta_Std_Dev (ms)"] = df["Lorta_Std_Dev (s)"] * 1000
df["Lotr_Average_Transfer_Time (ms)"] = df["Lotr_Average_Transfer_Time (s)"] * 1000
df["Lotr_Std_Dev (ms)"] = df["Lotr_Std_Dev (s)"] * 1000

# Function to format mean ± std and apply boldface to the smallest values
import math

def format_mean_std_bold(mean, std, min_value, min_threshold):
    """
    Format mean ± std for LaTeX, dynamically adjusting precision:
    - std is shown up to its first non-zero digit.
    - mean is displayed with the same precision as std.
    - Boldface applied if mean is within one std of the min value.
    """
    if std == 0:
        precision = 2  # Default to 2 decimal places if std is exactly 0
    else:
        # Find the position of the first non-zero digit in std
        precision = max(0, -math.floor(math.log10(abs(std))))

    # Format mean and std based on determined precision
    mean_str = f"{mean:.{precision}f}"
    std_str = f"{std:.{precision}f}"

    # Apply boldface if within one standard deviation of the minimum
    if mean <= min_value + min_threshold:
        return f"$\\mathbf{{{mean_str} \\pm {std_str}}}$"
    else:
        return f"${mean_str} \\pm {std_str}$"


# Generate LaTeX table with updated formatting
latex_table = """
\\begin{table*}[hb!]
\\setlength{\\tabcolsep}{5pt}
\\centering
\\begin{tabular}{l | r | ccc}
\\toprule
 Rank (r) & Num. Adapters & \\multicolumn{3}{c}{Transfer time (ms)} \\\\
 &  & Lora & Lotr & Lorta \\\\
\\midrule
"""

# Group by Rank (r)
for rank, group in df.groupby("Rank (r)"):
    first_row = True
    for _, row in group.iterrows():
        n = int(row["Repetitions (N)"])
        
        # Find the minimum value across the three methods
        min_value = min(row["Lora_Average_Transfer_Time (ms)"], row["Lotr_Average_Transfer_Time (ms)"], row["Lorta_Average_Transfer_Time (ms)"])
        
        # Compute threshold for bolding (one standard deviation)
        min_threshold = min(row["Lora_Std_Dev (ms)"], row["Lotr_Std_Dev (ms)"], row["Lorta_Std_Dev (ms)"])
        
        # Format transfer times with boldface where necessary
        lora = format_mean_std_bold(row["Lora_Average_Transfer_Time (ms)"], row["Lora_Std_Dev (ms)"], min_value, min_threshold)
        lotr = format_mean_std_bold(row["Lotr_Average_Transfer_Time (ms)"], row["Lotr_Std_Dev (ms)"], min_value, min_threshold)
        lorta = format_mean_std_bold(row["Lorta_Average_Transfer_Time (ms)"], row["Lorta_Std_Dev (ms)"], min_value, min_threshold)

        if first_row:
            latex_table += f"\\multirow{{{len(group)}}}{{*}}{{{rank}}} "
            first_row = False
        
        latex_table += f"& {n} & {lora} & {lotr} & {lorta} \\\\\n"

latex_table += """
\\bottomrule
\\end{tabular}
\\caption{GPU transfer times (Mean $\\pm$ Std) in milliseconds for Lora, Lotr, and Lorta at different ranks and number of concurrent adapters. Boldface indicates the smallest value (within one standard deviation).}
\\label{tab:gpu-transfer-times}
\\end{table*}
"""

# Display LaTeX code

# %%
print(latex_table)
# Out:
# \begin{table*}[hb!]
# \setlength{\tabcolsep}{5pt}
# \centering
# \begin{tabular}{l | r | ccc}
# \toprule
#  Rank (r) & Num. Adapters & \multicolumn{3}{c}{Transfer time (ms)} \\
#  &  & Lora & Lotr & Lorta \\
# \midrule
# \multirow{3}{*}{4} & 1 & $10 \pm 89$ & $0.4 \pm 0.2$ & $\mathbf{0.12 \pm 0.03}$ \\
# & 10 & $12.64 \pm 0.08$ & $3.25 \pm 0.05$ & $\mathbf{1.06 \pm 0.01}$ \\
# & 100 & $144 \pm 2$ & $17.1 \pm 0.2$ & $\mathbf{5.5 \pm 0.2}$ \\
# \multirow{3}{*}{64} & 1 & $23 \pm 5$ & $3.4 \pm 0.2$ & $\mathbf{1.08 \pm 0.01}$ \\
# & 10 & $216 \pm 2$ & $41.02 \pm 0.04$ & $\mathbf{8.811 \pm 0.005}$ \\
# & 100 & $2272 \pm 31$ & $375.1 \pm 0.2$ & $\mathbf{61.5 \pm 0.1}$ \\
#
# \bottomrule
# \end{tabular}
# \caption{GPU transfer times (Mean $\pm$ Std) in milliseconds for Lora, Lotr, and Lorta at different ranks and number of concurrent adapters. Boldface indicates the smallest value (within one standard deviation).}
# \label{tab:gpu-transfer-times}
# \end{table*}
